# %%
#in this first step I am importing both the geopandas library and the pandas library
import pandas as pd
import geopandas as gpd

# %%
parks=pd.read_csv('Data/L.A._County_Park_Needs_Assessment_-_Demographics (1).csv')

# %%
parks.sample()
# Out:
#      OBJECTID STUD_AR_ID                                    STUD_AR_NM  \
# 152       153        171  City of Claremont / Unincorporated Claremont
#
#                              STUD_AR_LBL  TOOLKIT_ID        Acres  AC_PER_1K  \
# 152  City of Claremont / Unic. Claremont         171  9343.034916   3.371267
#
#      RepPrkAc NEED_DESCP   PCT_Walk  ...  Pac_Island  Other_Race  Multi_Race  \
# 152   125.074        Low  71.294244  ...    0.117352    0.186697    4.155332
#
#      No_HS  HS_Grad  Some_College  College  unemprt_cy  SHAPE_Length  \
# 152      6       11            25       58        13.5  108101.56139
#
#        SHAPE_Area
# 152 -4.069810e+08
#
# [1 rows x 97 columns]

# %%
parks.head(10)
# Out:
#    OBJECTID STUD_AR_ID                                         STUD_AR_NM  \
# 0         1        129           City of LA Brentwood - Pacific Palisades
# 1         2        147                                City of LA Westlake
# 2         3        136                        City of LA Encino - Tarzana
# 3         4        139  City of LA Sunland - Tujunga - Lake View Terra...
# 4         5        059                      City of LA Central City North
# 5         6        138  City of LA Silver Lake - Echo Park - Elysian V...
# 6         7        120             City of LA Sun Valley - La Tuna Canyon
# 7         8        094        City of LA North Hollywood - Valley Village
# 8         9        096                                  City of LA Sylmar
# 9        10        117                        City of LA Arleta - Pacoima
#
#                                          STUD_AR_LBL  TOOLKIT_ID  \
# 0           City of LA Brentwood - Pacific Palisades         129
# 1                                City of LA Westlake         147
# 2                        City of LA Encino - Tarzana         136
# 3  City of LA Sunland - Tujunga - Lake View Terra...         139
# 4                      City of LA Central City North          59
# 5  City of LA Silver Lake - Echo Park - Elysian V...         138
# 6             City of LA Sun Valley - La Tuna Canyon         120
# 7        City of LA North Hollywood - Valley Village          94
# 8                                  City of LA Sylmar          96
# 9                        City of LA Arleta - Pacoima         117
#
#           Acres  AC_PER_1K  RepPrkAc NEED_DESCP   PCT_Walk  ...  Pac_Island  \
# 0  24319.323463   6.523099   378.979   Moderate  29.704955  ...    0.051892
# 1   1943.364931   0.668962    76.649  Very High  81.378611  ...    0.097918
# 2  12988.798545   8.805535   627.412   Moderate  10.459357  ...    0.128911
# 3  16428.801938   8.599252   559.218        Low  42.826803  ...    0.067242
# 4   2022.349957   1.554053    34.716       High  49.448705  ...    0.159536
# 5   4552.371487   8.837859   634.451   Moderate  55.523755  ...    0.081921
# 6  10504.568668   1.199641   110.397       High  29.382559  ...    0.091929
# 7   6791.468849   1.123886   158.387  Very High  39.173281  ...    0.109241
# 8   7888.760176   4.221127   342.861   Moderate  35.089855  ...    0.045065
# 9   6619.442128   4.540436   481.129       High  37.233899  ...    0.068378
#
#    Other_Race  Multi_Race  No_HS  HS_Grad  Some_College  College  unemprt_cy  \
# 0    0.228326    3.898845      2        4            15       79        12.6
# 1    0.242667    0.981736     40       21            18       22        18.2
# 2    0.225256    5.134746      6       14            25       55        14.2
# 3    0.223619    3.196347     14       25            33       29        15.2
# 4    0.235678    1.602611     29       19            20       32        17.4
# 5    0.254093    2.436789     16       14            21       48        18.0
# 6    0.230917    1.419425     30       26            24       20        17.1
# 7    0.378468    2.692969     16       19            30       35        18.8
# 8    0.171960    1.040061     28       28            26       18        14.9
# 9    0.138630    0.506749     41       29            19       11        17.6
#
#     SHAPE_Length    SHAPE_Area
# 0  167420.887603 -1.059345e+09
# 1   40570.381098 -8.465264e+07
# 2  111443.208133 -5.657898e+08
# 3  196258.103867 -7.156357e+08
# 4   60051.866287 -8.809321e+07
# 5   68554.981159 -1.983005e+08
# 6  119815.314922 -4.575772e+08
# 7   79857.545063 -2.958352e+08
# 8  112509.611564 -3.436330e+08
# 9   83955.570263 -2.883417e+08
#
# [10 rows x 97 columns]

# %%
type(parks)
# Out:
# pandas.core.frame.DataFrame

# %%
parks.shape
# Out:
# (189, 97)

# %%
parks['NEED_DESCP'].sample
# Out:
# <bound method NDFrame.sample of 0       Moderate
# 1      Very High
# 2       Moderate
# 3            Low
# 4           High
#          ...
# 184     Very Low
# 185     Moderate
# 186     Very Low
# 187    Very High
# 188          ***
# Name: NEED_DESCP, Length: 189, dtype: object>

# %%
parks['NEED_DESCP'].value_counts()
# Out:
# Moderate             44
# Very High            43
# Low                  37
# Very Low             33
# High                 29
# Not Participating     2
# ***                   1
# Name: NEED_DESCP, dtype: int64

# %%
parks['MEAN_Asthma'].sample()
# Out:
# 160    49.154051
# Name: MEAN_Asthma, dtype: float64

# %%
parks['MEAN_Asthma'].value_counts()
# Out:
# 11.661877    1
# 25.053865    1
# 69.682463    1
# 32.606992    1
# 49.336215    1
#             ..
# 42.749756    1
# 46.663589    1
# 42.146158    1
# 58.298665    1
# 43.426965    1
# Name: MEAN_Asthma, Length: 189, dtype: int64

# %%
#Selecting the columns I wish to explore further, including the park need description, the mean rate of asthma, the city name, and the latitude and longitude. 
parks[['NEED_DESCP','MEAN_Asthma','STUD_AR_LBL','SHAPE_Length','SHAPE_Area']]
# Out:
#     NEED_DESCP  MEAN_Asthma  \
# 0     Moderate    11.661877
# 1    Very High    49.948183
# 2     Moderate    29.772325
# 3          Low    36.527576
# 4         High    65.344114
# ..         ...          ...
# 184   Very Low    49.390000
# 185   Moderate    24.560968
# 186   Very Low    19.320513
# 187  Very High    20.493438
# 188        ***    43.426965
#
#                                            STUD_AR_LBL  SHAPE_Length  \
# 0             City of LA Brentwood - Pacific Palisades  1.674209e+05
# 1                                  City of LA Westlake  4.057038e+04
# 2                          City of LA Encino - Tarzana  1.114432e+05
# 3    City of LA Sunland - Tujunga - Lake View Terra...  1.962581e+05
# 4                        City of LA Central City North  6.005187e+04
# ..                                                 ...           ...
# 184             City of Avalon / Unic. Channel Islands  3.284736e+05
# 185                 Unincorporated Castaic - Val Verde  4.643656e+05
# 186  Unincorporated Stevenson - Newhall Ranch - Cas...  1.932126e+05
# 187          Unincorporated East San Gabriel - Arcadia  8.734921e+04
# 188                         *Entire Los Angeles County  2.918802e+06
#
#        SHAPE_Area
# 0   -1.059345e+09
# 1   -8.465264e+07
# 2   -5.657898e+08
# 3   -7.156357e+08
# 4   -8.809321e+07
# ..            ...
# 184 -2.083636e+09
# 185 -5.873927e+09
# 186 -1.363426e+09
# 187 -6.140079e+07
# 188 -1.138632e+11
#
# [189 rows x 5 columns]

# %%
mean_asthma = parks['MEAN_Asthma'].value_counts()
mean_asthma
# Out:
# 11.661877    1
# 25.053865    1
# 69.682463    1
# 32.606992    1
# 49.336215    1
#             ..
# 42.749756    1
# 46.663589    1
# 42.146158    1
# 58.298665    1
# 43.426965    1
# Name: MEAN_Asthma, Length: 189, dtype: int64

# %%
mean_asthma = mean_asthma.reset_index()
mean_asthma
# Out:
#          index  MEAN_Asthma
# 0    11.661877            1
# 1    25.053865            1
# 2    69.682463            1
# 3    32.606992            1
# 4    49.336215            1
# ..         ...          ...
# 184  42.749756            1
# 185  46.663589            1
# 186  42.146158            1
# 187  58.298665            1
# 188  43.426965            1
#
# [189 rows x 2 columns]

# %%
mean_asthma.columns.to_list()
# Out:
# ['index', 'MEAN_Asthma']

# %%
mean_asthma.columns = ['MEAN_Asthma','STUD_AR_LBL']

# %%
mean_asthma.plot()
# Out:
# <AxesSubplot: >

# %%
mean_asthma.plot.bar(x = 'STUD_AR_LBL', y = 'MEAN_Asthma', title = 'Mean Asthma Rate per City')
# Out:
# <AxesSubplot: title={'center': 'Mean Asthma Rate per City'}, xlabel='STUD_AR_LBL'>
